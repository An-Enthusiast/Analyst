# %% [markdown]
# ##Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import yfinance as yf

try:
  from finta import TA
except:
  # !pip install finta
  from finta import TA

try:
  from backtesting import Backtest,Strategy
  from backtesting.lib import crossover
  from backtesting.test import SMA
except:
  # !pip install backtesting
  from backtesting import Backtest,Strategy
  from backtesting.lib import crossover
  from backtesting.test import SMA
# Out:
# Collecting finta
#   Downloading finta-1.3-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from finta) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from finta) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->finta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->finta) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->finta) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->finta) (1.17.0)
# Downloading finta-1.3-py3-none-any.whl (29 kB)
# Installing collected packages: finta
# Successfully installed finta-1.3
# Collecting backtesting
#   Downloading backtesting-0.6.5-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from backtesting) (2.0.2)
# Requirement already satisfied: pandas!=0.25.0,>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from backtesting) (2.2.2)
# Requirement already satisfied: bokeh!=3.0.*,!=3.2.*,>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from backtesting) (3.7.3)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from bokeh!=3.0.*,!=3.2.*,>=3.0.0->backtesting) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.11/dist-packages (from bokeh!=3.0.*,!=3.2.*,>=3.0.0->backtesting) (1.3.2)
# Requirement already satisfied: narwhals>=1.13 in /usr/local/lib/python3.11/dist-packages (from bokeh!=3.0.*,!=3.2.*,>=3.0.0->backtesting) (1.48.1)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.11/dist-packages (from bokeh!=3.0.*,!=3.2.*,>=3.0.0->backtesting) (25.0)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from bokeh!=3.0.*,!=3.2.*,>=3.0.0->backtesting) (11.3.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.11/dist-packages (from bokeh!=3.0.*,!=3.2.*,>=3.0.0->backtesting) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.11/dist-packages (from bokeh!=3.0.*,!=3.2.*,>=3.0.0->backtesting) (6.4.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.11/dist-packages (from bokeh!=3.0.*,!=3.2.*,>=3.0.0->backtesting) (2025.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas!=0.25.0,>=0.25.0->backtesting) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas!=0.25.0,>=0.25.0->backtesting) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas!=0.25.0,>=0.25.0->backtesting) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=2.9->bokeh!=3.0.*,!=3.2.*,>=3.0.0->backtesting) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas!=0.25.0,>=0.25.0->backtesting) (1.17.0)
# Downloading backtesting-0.6.5-py3-none-any.whl (192 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.1/192.1 kB 6.6 MB/s eta 0:00:00
# Installing collected packages: backtesting
# Successfully installed backtesting-0.6.5
# /usr/local/lib/python3.11/dist-packages/backtesting/_plotting.py:55: UserWarning: Jupyter Notebook detected. Setting Bokeh output to notebook. This may not work in Jupyter clients without JavaScript support, such as old IDEs. Reset with `backtesting.set_bokeh_output(notebook=False)`.
#   warnings.warn('Jupyter Notebook detected. '

# %%
ohlcv=yf.download(tickers='KO',period='5y',interval='1d',auto_adjust=True,)
display(ohlcv.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker             KO         KO         KO         KO        KO
# Date
# 2020-08-05  40.575558  40.618521  40.223250  40.300586  10498700
# 2020-08-06  40.798969  40.841933  40.042795  40.094354  10745000
# 2020-08-07  41.073952  41.314555  40.566972  40.790388  11669700
# 2020-08-10  41.005199  41.486398  40.953641  41.297357  11888000
# 2020-08-11  41.185654  41.804342  40.988018  41.641075  16531600

# %% [markdown]
# ##Cleaning

# %%
ohlcv.columns=ohlcv.columns.droplevel(level=1)
ohlcv.columns.name = None # Remove the name of the columns index
display(ohlcv.head())
# Out:
#                 Close       High        Low       Open    Volume
# Date
# 2020-08-05  40.575558  40.618521  40.223250  40.300586  10498700
# 2020-08-06  40.798969  40.841933  40.042795  40.094354  10745000
# 2020-08-07  41.073952  41.314555  40.566972  40.790388  11669700
# 2020-08-10  41.005199  41.486398  40.953641  41.297357  11888000
# 2020-08-11  41.185654  41.804342  40.988018  41.641075  16531600

# %% [markdown]
# ##Strategies

# %% [markdown]
# ### Simple SMA strategy

# %%
class MySmaStratergy(Strategy):
  n1=12
  n2=20
  def init(self):
    self.sma1=self.I(SMA,self.data.Close,self.n1)
    self.sma2=self.I(SMA,self.data.Close,self.n2)

  def next(self):
    if crossover(self.sma1,self.sma2):
      self.buy()
    elif crossover(self.sma2,self.sma1):
      self.position.close

# %%
bt1=Backtest(ohlcv,MySmaStratergy,cash=10000,exclusive_orders=True,finalize_trades=True)
stats=bt1.run()
# Out:
# Backtest.run:   0%|          | 0/1235 [00:00<?, ?bar/s]

# %%
display(stats)
# Out:
# Start                     2020-08-05 00:00:00
# End                       2025-08-04 00:00:00
# Duration                   1825 days 00:00:00
# Exposure Time [%]                    96.09562
# Equity Final [$]                  15833.84033
# Equity Peak [$]                    16905.2446
# Return [%]                            58.3384
# Buy & Hold Return [%]                63.38056
# Return (Ann.) [%]                     9.66708
# Volatility (Ann.) [%]                 17.6374
# CAGR [%]                              6.55144
# Sharpe Ratio                           0.5481
# Sortino Ratio                         0.86545
# Calmar Ratio                          0.56075
# Alpha [%]                            -0.98194
# Beta                                  0.93594
# Max. Drawdown [%]                   -17.23953
# Avg. Drawdown [%]                    -3.02768
# Max. Drawdown Duration      746 days 00:00:00
# Avg. Drawdown Duration       40 days 00:00:00
# # Trades                                   35
# Win Rate [%]                         62.85714
# Best Trade [%]                       14.59628
# Worst Trade [%]                     -12.57803
# Avg. Trade [%]                        1.32472
# Max. Trade Duration         121 days 00:00:00
# Avg. Trade Duration          51 days 00:00:00
# Profit Factor                         2.04007
# Expectancy [%]                        1.48701
# SQN                                   1.25459
# Kelly Criterion                       0.28761
# _strategy                      MySmaStratergy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %%
#bt1.plot()

# %% [markdown]
# ###RSI Strategy

# %%
rsi=TA.RSI(ohlcv,14)

# %%
class MyRSIStrategy(Strategy):
  period=20
  def init(self):
    self.rsi=self.I(TA.RSI,self.data.df,self.period)[21:]

  def next(self):
    if self.rsi[-1]<30:
      self.buy()
    elif self.rsi[-1]>70:
      self.sell()

# %%
bt4=Backtest(ohlcv, MyRSIStrategy, cash=10000,   exclusive_orders=True, finalize_trades=True )
stats=bt4.run()
# Out:
# Backtest.run:   0%|          | 0/1254 [00:00<?, ?bar/s]

# %%
display(stats)
# Out:
# Start                     2020-08-05 00:00:00
# End                       2025-08-04 00:00:00
# Duration                   1825 days 00:00:00
# Exposure Time [%]                    99.84064
# Equity Final [$]                   3188.68819
# Equity Peak [$]                   10040.00521
# Return [%]                          -68.11312
# Buy & Hold Return [%]                69.95453
# Return (Ann.) [%]                   -20.50737
# Volatility (Ann.) [%]                 15.3248
# CAGR [%]                            -14.60004
# Sharpe Ratio                         -1.33818
# Sortino Ratio                        -1.48794
# Calmar Ratio                         -0.28949
# Alpha [%]                           -13.35856
# Beta                                 -0.78272
# Max. Drawdown [%]                   -70.83842
# Avg. Drawdown [%]                   -36.45077
# Max. Drawdown Duration     1809 days 00:00:00
# Avg. Drawdown Duration      911 days 00:00:00
# # Trades                                   52
# Win Rate [%]                         38.46154
# Best Trade [%]                        1.27929
# Worst Trade [%]                     -21.47162
# Avg. Trade [%]                       -2.18135
# Max. Trade Duration         487 days 00:00:00
# Avg. Trade Duration          36 days 00:00:00
# Profit Factor                         0.09998
# Expectancy [%]                       -2.09237
# SQN                                  -2.91316
# Kelly Criterion                      -4.87209
# _strategy                       MyRSIStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %%
#bt4.plot()

# %% [markdown]
# ###Combination

# %%
display(TA.RSI(ohlcv,15))
display(TA.SMA(ohlcv,20))
# Out:
# Date
# 2020-08-05           NaN
# 2020-08-06    100.000000
# 2020-08-07    100.000000
# 2020-08-10     86.778886
# 2020-08-11     90.362226
#                  ...
# 2025-07-29     47.021280
# 2025-07-30     43.428392
# 2025-07-31     39.062865
# 2025-08-01     45.663576
# 2025-08-04     46.305996
# Name: 15 period RSI, Length: 1255, dtype: float64
# Date
# 2020-08-05        NaN
# 2020-08-06        NaN
# 2020-08-07        NaN
# 2020-08-10        NaN
# 2020-08-11        NaN
#                ...
# 2025-07-29    69.8735
# 2025-07-30    69.7275
# 2025-07-31    69.5765
# 2025-08-01    69.4520
# 2025-08-04    69.3495
# Name: 20 period SMA, Length: 1255, dtype: float64

# %%
class MyCombinationStrategy1(Strategy):
  n1=30
  n2=70
  period=14
  sl=0.93
  tgt=1.2

  def init(self):
    self.rsi=self.I(TA.RSI,self.data.df,self.period)
    self.sma1=self.I(TA.SMA,self.data.df,self.n1)
    self.sma2=self.I(TA.SMA,self.data.df,self.n2)
    self.crossover_series=[]
  def next(self):
    price = self.data.Close[-1]

    # Ensure enough history to look back 3 candles
    if len(self.sma1) < 3 or len(self.sma2) < 3:
        return

    # Check if crossover happened 2 candles ago
    if (
        self.sma1[-2] < self.sma2[-2] and  # 1 candles ago: before crossover
        self.sma1[-1] > self.sma2[-2] and  # current candles ago: crossover
        self.sma1[-1] > self.sma2[-1] and  # trend still up
        30 < self.rsi[-1] < 80             # RSI filter
        ):
      self.buy(
      sl=price * self.sl,
      tp=price * self.tgt
        )
    elif(
        (self.sma1[-2] > self.sma2[-2] and  # 3 candles ago: before crossover
        self.sma1[-1] < self.sma2[-1]) or
        (self.rsi[-1]<30 or self.rsi[-1]>80)
        ):
      self.position.close()

# %%
bt5=Backtest(ohlcv, MyCombinationStrategy1, cash=10000,   exclusive_orders=True, finalize_trades=True )
stats=bt5.run()
# Out:
# Backtest.run:   0%|          | 0/1185 [00:00<?, ?bar/s]

# %%
display(stats)
# Out:
# Start                     2020-08-05 00:00:00
# End                       2025-08-04 00:00:00
# Duration                   1825 days 00:00:00
# Exposure Time [%]                    49.08367
# Equity Final [$]                  13293.42545
# Equity Peak [$]                   13730.68376
# Return [%]                           32.93425
# Buy & Hold Return [%]                48.57806
# Return (Ann.) [%]                     5.88292
# Volatility (Ann.) [%]                11.07271
# CAGR [%]                              4.00927
# Sharpe Ratio                           0.5313
# Sortino Ratio                         0.80921
# Calmar Ratio                          0.37116
# Alpha [%]                            13.60479
# Beta                                  0.39791
# Max. Drawdown [%]                   -15.85003
# Avg. Drawdown [%]                     -2.8085
# Max. Drawdown Duration      712 days 00:00:00
# Avg. Drawdown Duration       41 days 00:00:00
# # Trades                                    7
# Win Rate [%]                         57.14286
# Best Trade [%]                       20.38544
# Worst Trade [%]                      -6.66374
# Avg. Trade [%]                        4.16112
# Max. Trade Duration         245 days 00:00:00
# Avg. Trade Duration         127 days 00:00:00
# Profit Factor                         3.44227
# Expectancy [%]                        4.66115
# SQN                                   1.04271
# Kelly Criterion                       0.38796
# _strategy                 MyCombinationStr...
# _equity_curve                             ...
# _trades                      Size  EntryBa...
# dtype: object

# %%
#bt5.plot()

# %%
stats._trades
# Out:
#    Size  EntryBar  ExitBar  EntryPrice  ExitPrice         SL         TP  \
# 0   215       162      290   46.418325  47.040634  43.422838  56.029468
# 1   202       325      431   50.078960  60.287778  46.723028  60.287778
# 2   209       504      538   58.158380  54.282855  54.121293  69.833926
# 3   197       584      632   57.560452  55.557958  53.685341  69.271408
# 4   188       675      706   58.375954  56.497989  54.376534  70.163269
# 5   190       837     1004   55.732622  67.074257  51.982549  67.074257
# 6   187      1138     1233   68.365825  71.040001  63.708555  82.204587
#
#            PnL  Commission  ReturnPct  EntryTime   ExitTime Duration   Tag  \
# 0   133.796447         0.0   0.013407 2021-03-29 2021-09-29 184 days  None
# 1  2062.181111         0.0   0.203854 2021-11-17 2022-04-21 155 days  None
# 2  -809.984838         0.0  -0.066637 2022-08-05 2022-09-23  49 days  None
# 3  -394.491337         0.0  -0.034789 2022-11-29 2023-02-08  71 days  None
# 4  -353.057358         0.0  -0.032170 2023-04-12 2023-05-25  43 days  None
# 5  2154.910546         0.0   0.203501 2023-12-01 2024-08-02 245 days  None
# 6   500.070878         0.0   0.039116 2025-02-14 2025-07-03 139 days  None
#
#    Entry_RSI(df,14)  Exit_RSI(df,14)  Entry_SMA(df,30)  Exit_SMA(df,30)  \
# 0         72.919533        30.327540         44.555195        49.303872
# 1         52.437012        75.292612         49.494530        56.363697
# 2         53.131458        30.465843         57.523447        56.966954
# 3         66.743431        38.107271         55.077705        56.987702
# 4         67.922621        24.278335         56.718982        59.159536
# 5         70.521843        75.813896         54.097122        62.879750
# 6         72.418319        55.103088         62.368044        70.722530
#
#    Entry_SMA(df,70)  Exit_SMA(df,70)
# 0         44.391159        49.409902
# 1         49.346831        55.580743
# 2         57.386695        57.094793
# 3         54.699172        57.139800
# 4         56.489072        57.630921
# 5         53.893275        61.516037
# 6         62.182567        70.767855

# %% [markdown]
# ###MACD Crossover

# %%
class MyMACDStratergy(Strategy):
  n1=12
  n2=26
  n3=9

  def init(self):
    self.macd=self.I(TA.MACD,self.data.df,self.n1,self.n2,self.n3)[0][25:]          #TA.MACD(df,period_fast,period_slow,signal)=>[[MACD],[SIGNAL]]
    self.signal=self.I(TA.MACD,self.data.df,self.n1,self.n2,self.n3)[1][25:]

  def next(self):
    if crossover(self.macd, self.signal):
      self.buy()
    elif crossover(self.signal, self.macd):
      self.sell()

# %%
bt2=Backtest(ohlcv,MyMACDStratergy, cash=10000, exclusive_orders=True, finalize_trades=True )
stats=bt2.run()
# Out:
# Backtest.run:   0%|          | 0/1254 [00:00<?, ?bar/s]

# %%
display(stats)
# Out:
# Start                     2020-08-05 00:00:00
# End                       2025-08-04 00:00:00
# Duration                   1825 days 00:00:00
# Exposure Time [%]                    99.36255
# Equity Final [$]                   2859.77992
# Equity Peak [$]                   10214.47914
# Return [%]                           -71.4022
# Buy & Hold Return [%]                69.95453
# Return (Ann.) [%]                    -22.2262
# Volatility (Ann.) [%]                13.17179
# CAGR [%]                             -15.8742
# Sharpe Ratio                         -1.68741
# Sortino Ratio                        -1.70568
# Calmar Ratio                         -0.30379
# Alpha [%]                           -73.61983
# Beta                                   0.0317
# Max. Drawdown [%]                    -73.1631
# Avg. Drawdown [%]                    -36.7976
# Max. Drawdown Duration     1809 days 00:00:00
# Avg. Drawdown Duration      906 days 00:00:00
# # Trades                                   91
# Win Rate [%]                         39.56044
# Best Trade [%]                         4.9505
# Worst Trade [%]                     -13.92263
# Avg. Trade [%]                       -1.37424
# Max. Trade Duration          77 days 00:00:00
# Avg. Trade Duration          20 days 00:00:00
# Profit Factor                         0.29557
# Expectancy [%]                       -1.32519
# SQN                                  -4.29532
# Kelly Criterion                      -1.12919
# _strategy                     MyMACDStratergy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %%
#bt2.plot()

# %% [markdown]
# ###VWAP Strategy

# %%
display(TA.VWAP(ohlcv))
# Out:
# Date
# 2020-08-05    40.472443
# 2020-08-06    40.517353
# 2020-08-07    40.683217
# 2020-08-10    40.806656
# 2020-08-11    40.946641
#                 ...
# 2025-07-29    56.053961
# 2025-07-30    56.061029
# 2025-07-31    56.071937
# 2025-08-01    56.082674
# 2025-08-04    56.089825
# Name: VWAP., Length: 1255, dtype: float64

# %%
class MyVWAPStrategy(Strategy):
  def init(self):
    self.vwap=self.I(TA.VWAP,self.data.df)

  def next(self):
    if crossover(self.data.Close,self.vwap):
      self.buy()
    elif crossover(self.vwap,self.data.Open):
      self.sell()

# %%
bt3=Backtest(ohlcv,MyVWAPStrategy, cash=10000,   exclusive_orders=True, finalize_trades=True )
stats=bt3.run()
# Out:
# Backtest.run:   0%|          | 0/1254 [00:00<?, ?bar/s]

# %%
display(stats)
# Out:
# Start                     2020-08-05 00:00:00
# End                       2025-08-04 00:00:00
# Duration                   1825 days 00:00:00
# Exposure Time [%]                    99.04382
# Equity Final [$]                  10943.71487
# Equity Peak [$]                    11684.3813
# Return [%]                            9.43715
# Buy & Hold Return [%]                69.95453
# Return (Ann.) [%]                     1.82728
# Volatility (Ann.) [%]                16.90257
# CAGR [%]                              1.25301
# Sharpe Ratio                          0.10811
# Sortino Ratio                         0.15481
# Calmar Ratio                          0.08468
# Alpha [%]                           -46.63398
# Beta                                  0.80154
# Max. Drawdown [%]                   -21.57751
# Avg. Drawdown [%]                    -6.87199
# Max. Drawdown Duration      834 days 00:00:00
# Avg. Drawdown Duration      138 days 00:00:00
# # Trades                                   23
# Win Rate [%]                         30.43478
# Best Trade [%]                       29.87945
# Worst Trade [%]                        -5.287
# Avg. Trade [%]                        0.39227
# Max. Trade Duration         649 days 00:00:00
# Avg. Trade Duration          79 days 00:00:00
# Profit Factor                         1.43931
# Expectancy [%]                        0.61145
# SQN                                   0.32225
# Kelly Criterion                       0.07492
# _strategy                      MyVWAPStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %%
#bt3.plot()

# %% [markdown]
# ###Combination2

# %%
display(TA.MACD(ohlcv,12,26,9))
display(TA.WMA(ohlcv,20))
# Out:
#                 MACD    SIGNAL
# Date
# 2020-08-05  0.000000  0.000000
# 2020-08-06  0.005012  0.002785
# 2020-08-07  0.014914  0.007756
# 2020-08-10  0.016570  0.010741
# 2020-08-11  0.024301  0.014775
# ...              ...       ...
# 2025-07-29 -0.385890 -0.299796
# 2025-07-30 -0.408504 -0.321537
# 2025-07-31 -0.490169 -0.355264
# 2025-08-01 -0.471187 -0.378448
# 2025-08-04 -0.442969 -0.391352
#
# [1255 rows x 2 columns]
# Date
# 2020-08-05          NaN
# 2020-08-06          NaN
# 2020-08-07          NaN
# 2020-08-10          NaN
# 2020-08-11          NaN
#                 ...
# 2025-07-29    69.506904
# 2025-07-30    69.399904
# 2025-07-31    69.224904
# 2025-08-01    69.156666
# 2025-08-04    69.109809
# Name: 20 period WMA., Length: 1255, dtype: float64

# %%
class MyCombinationStrategy2(Strategy):
  n1=12
  n2=26
  n3=9
  sl=0.96

  def init(self):
    self.macd=self.I(TA.MACD,self.data.df,self.n1,self.n2,self.n3)[0]         #TA.MACD(df,period_fast,period_slow,signal)=>[[MACD],[SIGNAL]]
    self.signal=self.I(TA.MACD,self.data.df,self.n1,self.n2,self.n3)[1]
    self.wma=self.I(TA.WMA,self.data.df)[25:]

  def next(self):
    self.price=self.data.Close[-1]
    if (self.macd <0.3)and (self.signal<0.3) and crossover(self.macd,self.signal):
      self.buy(
          sl=self.price*self.sl
      )
    elif (self.macd >0)and (self.signal>0) and crossover(self.signal,self.macd):
      self.position.close()

# %%
bt6=Backtest(ohlcv, MyCombinationStrategy2, cash=10000, exclusive_orders=True, finalize_trades=True )
stats=bt6.run()
# Out:
# Backtest.run:   0%|          | 0/1254 [00:00<?, ?bar/s]

# %%
display(stats)
# Out:
# Start                     2020-08-05 00:00:00
# End                       2025-08-04 00:00:00
# Duration                   1825 days 00:00:00
# Exposure Time [%]                    45.73705
# Equity Final [$]                  18363.73896
# Equity Peak [$]                   20121.09878
# Return [%]                           83.63739
# Buy & Hold Return [%]                69.95453
# Return (Ann.) [%]                    12.98025
# Volatility (Ann.) [%]                11.47344
# CAGR [%]                              8.75477
# Sharpe Ratio                          1.13133
# Sortino Ratio                          2.1023
# Calmar Ratio                          1.48619
# Alpha [%]                            57.60661
# Beta                                  0.37211
# Max. Drawdown [%]                    -8.73392
# Avg. Drawdown [%]                    -1.80801
# Max. Drawdown Duration      224 days 00:00:00
# Avg. Drawdown Duration       39 days 00:00:00
# # Trades                                   31
# Win Rate [%]                         54.83871
# Best Trade [%]                       13.25091
# Worst Trade [%]                      -4.71731
# Avg. Trade [%]                        1.98182
# Max. Trade Duration          70 days 00:00:00
# Avg. Trade Duration          26 days 00:00:00
# Profit Factor                         3.37727
# Expectancy [%]                        2.10141
# SQN                                   2.01369
# Kelly Criterion                       0.35968
# _strategy                 MyCombinationStr...
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %%
#bt6.plot()

# %%
stats._trades
# Out:
#     Size  EntryBar  ExitBar  EntryPrice  ExitPrice         SL    TP  \
# 0    238        17       33   41.890266  42.541214  39.785698  None
# 1    231        46       53   43.892540  43.216873  41.962207  None
# 2    226        56       58   44.178404  43.147582  42.145155  None
# 3    214        68       81   45.538401  45.476411  43.716863  None
# 4    228       125      173   42.735085  46.638397  41.034053  None
# 5    218       235      252   48.737082  50.058611  46.387412  None
# 6    226       297      325   48.255959  50.078960  46.222775  None
# 7    230       340      368   49.305601  54.934097  47.549509  None
# 8    228       410      438   55.291077  59.238495  52.774530  None
# 9    232       458      465   58.149557  56.346270  56.346270  None
# 10   231       475      490   56.769085  57.143831  54.296503  None
# 11   229       498      507   57.509426  58.158382  55.288030  None
# 12   257       553      593   51.824658  58.691898  49.380458  None
# 13   266       627      636   56.689144  55.826848  54.581796  None
# 14   266       636      640   55.826848  55.622864  53.940916  None
# 15   266       640      686   55.622864  59.356983  53.513661  None
# 16   278       719      733   56.740908  57.173042  54.220126  None
# 17   278       733      740   57.173042  57.201281  55.157252  None
# 18   278       740      754   57.201281  58.067397  55.039764  None
# 19   292       786      791   55.320814  52.998673  52.998673  None
# 20   302       806      848   51.335439  56.239538  49.254694  None
# 21   294       880      882   57.750740  57.454234  55.587616  None
# 22   289       892      898   58.334181  57.291647  56.230364  None
# 23   284       907      921   58.405488  57.933080  56.120171  None
# 24   282       934      954   58.357281  60.565086  56.041501  None
# 25   273       992     1013   62.638149  66.670233  59.946072  None
# 26   289      1083     1111   62.842572  59.878092  59.878092  None
# 27   282      1117     1151   61.436591  69.400772  58.704716  None
# 28   275      1204     1214   71.183884  70.876069  68.336528  None
# 29   271      1218     1222   71.759780  70.379997  68.965649  None
# 30   266      1232     1241   71.690002  68.803198  68.803198  None
#
#             PnL  Commission  ReturnPct  EntryTime   ExitTime Duration   Tag  \
# 0    154.925465         0.0   0.015539 2020-08-28 2020-09-22  25 days  None
# 1   -156.079132         0.0  -0.015394 2020-10-09 2020-10-20  11 days  None
# 2   -232.965767         0.0  -0.023333 2020-10-23 2020-10-27   4 days  None
# 3    -13.265898         0.0  -0.001361 2020-11-10 2020-11-30  20 days  None
# 4    889.955148         0.0   0.091337 2021-02-03 2021-04-14  70 days  None
# 5    288.093122         0.0   0.027115 2021-07-13 2021-08-05  23 days  None
# 6    411.998300         0.0   0.037778 2021-10-08 2021-11-17  40 days  None
# 7   1294.554163         0.0   0.114155 2021-12-09 2022-01-20  42 days  None
# 8    900.011427         0.0   0.071393 2022-03-22 2022-05-02  41 days  None
# 9   -418.362665         0.0  -0.031011 2022-05-31 2022-06-09   9 days  None
# 10    86.566201         0.0   0.006601 2022-06-24 2022-07-18  24 days  None
# 11   148.610878         0.0   0.011284 2022-07-28 2022-08-10  13 days  None
# 12  1764.880668         0.0   0.132509 2022-10-14 2022-12-12  59 days  None
# 13  -229.370665         0.0  -0.015211 2023-02-01 2023-02-14  13 days  None
# 14   -54.259731         0.0  -0.003654 2023-02-14 2023-02-21   7 days  None
# 15   993.275568         0.0   0.067133 2023-02-21 2023-04-27  65 days  None
# 16   120.133302         0.0   0.007616 2023-06-14 2023-07-06  22 days  None
# 17     7.850619         0.0   0.000494 2023-07-06 2023-07-17  11 days  None
# 18   240.780194         0.0   0.015142 2023-07-17 2023-08-04  18 days  None
# 19  -678.065077         0.0  -0.041976 2023-09-20 2023-09-27   7 days  None
# 20  1481.037891         0.0   0.095530 2023-10-18 2023-12-18  61 days  None
# 21   -87.172512         0.0  -0.005134 2024-02-05 2024-02-07   2 days  None
# 22  -301.292328         0.0  -0.017872 2024-02-22 2024-03-01   8 days  None
# 23  -134.163754         0.0  -0.008088 2024-03-14 2024-04-04  21 days  None
# 24   622.600975         0.0   0.037833 2024-04-23 2024-05-21  28 days  None
# 25  1100.758824         0.0   0.064371 2024-07-17 2024-08-15  29 days  None
# 26  -856.734726         0.0  -0.047173 2024-11-22 2025-01-06  45 days  None
# 27  2245.898797         0.0   0.129633 2025-01-15 2025-03-06  50 days  None
# 28   -84.649185         0.0  -0.004324 2025-05-21 2025-06-05  15 days  None
# 29  -373.921225         0.0  -0.019228 2025-06-11 2025-06-17   6 days  None
# 30  -767.889917         0.0  -0.040268 2025-07-02 2025-07-16  14 days  None
#
#     Entry_MACD(df,12,26,9)_0  Exit_MACD(df,12,26,9)_0  \
# 0                   0.118217                 0.352246
# 1                   0.169462                 0.181348
# 2                   0.217490                 0.149880
# 3                   0.383859                 0.604351
# 4                  -0.765586                 0.608986
# 5                  -0.019294                 0.433517
# 6                  -0.460217                 0.421119
# 7                  -0.132356                 0.975850
# 8                  -0.108942                 0.753574
# 9                  -0.076054                -0.296002
# 10                 -0.435905                 0.038295
# 11                  0.147963                 0.266989
# 12                 -1.410624                 1.137340
# 13                 -0.403059                -0.491848
# 14                 -0.491848                -0.448977
# 15                 -0.448977                 0.725480
# 16                 -0.552515                -0.117997
# 17                 -0.117997                -0.154214
# 18                 -0.154214                 0.214405
# 19                 -0.510859                -0.753502
# 20                 -1.156770                 0.648729
# 21                  0.282937                 0.245145
# 22                  0.265332                 0.151398
# 23                  0.165261                 0.110306
# 24                 -0.034162                 0.675350
# 25                  0.375294                 1.121012
# 26                 -1.338310                -0.544001
# 27                 -0.460130                 1.746130
# 28                  0.062347                 0.035961
# 29                  0.151280                -0.038202
# 30                 -0.053722                -0.297870
#
#     Entry_MACD(df,12,26,9)_1  Exit_MACD(df,12,26,9)_1  Entry_WMA(df)  \
# 0                   0.028438                 0.440302      41.495376
# 1                   0.084337                 0.182152      43.140259
# 2                   0.190843                 0.180415      43.508508
# 3                   0.022913                 0.706267      43.936240
# 4                  -0.819145                 0.636724      42.539327
# 5                  -0.065830                 0.492990      48.263260
# 6                  -0.553311                 0.472725      47.770820
# 7                  -0.198217                 1.032570      48.942572
# 8                  -0.199904                 0.965611      54.384236
# 9                  -0.070007                -0.170908      57.634527
# 10                 -0.617448                 0.112021      55.783987
# 11                  0.019422                 0.270784      57.294741
# 12                 -1.441657                 1.162114      50.718420
# 13                 -0.457162                -0.494917      56.454458
# 14                 -0.494917                -0.485910      55.539412
# 15                 -0.485910                 0.768357      55.413932
# 16                 -0.615200                -0.135133      56.514595
# 17                 -0.135133                -0.212180      57.066346
# 18                 -0.212180                 0.309258      56.742076
# 19                 -0.545680                -0.613098      55.238308
# 20                 -1.255680                 0.697104      50.823876
# 21                  0.272081                 0.264965      57.434896
# 22                  0.152451                 0.221323      57.656796
# 23                  0.081746                 0.229062      57.719179
# 24                 -0.189220                 0.735953      57.409889
# 25                  0.270214                 1.162163      62.002082
# 26                 -1.554244                -0.455524      61.628244
# 27                 -0.510157                 1.907912      60.671055
# 28                  0.023635                 0.080995      70.759786
# 29                  0.093156                 0.083049      71.216538
# 30                 -0.175169                -0.180214      70.524445
#
#     Exit_WMA(df)
# 0      43.452469
# 1      43.431316
# 2      43.409950
# 3      45.657590
# 4      46.781008
# 5      50.302423
# 6      50.410598
# 7      54.805812
# 8      59.038253
# 9      57.062831
# 10     57.037194
# 11     58.018840
# 12     59.012917
# 13     55.539412
# 14     55.413932
# 15     59.585999
# 16     57.066346
# 17     56.742076
# 18     58.140412
# 19     54.212289
# 20     56.494806
# 21     57.479531
# 22     57.722047
# 23     58.069125
# 24     60.761549
# 25     66.556447
# 26     60.967849
# 27     69.774888
# 28     70.929250
# 29     70.873660
# 30     69.659555
